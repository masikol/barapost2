# %%
from src.args.ProberArgs import ProberArgs
from src.prober_kernel import ProberKernel
from src.util.BarapostWorkDirManager import BarapostWorkDirManager

# %%
args = ProberArgs(
    input_fpaths=[
        '/home/masikol/cager/repos/barapost2/tests/test_remote_blast/data/query_corona_seq.fasta',
        # '/home/masikol/cager/repos/barapost2/tests/test_remote_blast/data/711bf04d-20f5-4418-9712-16168ef98999.fasta',
        # '/home/masikol/cager/repos/barapost2/tests/test_read_write/data/test_input/some_seqs.fasta',
        '/home/masikol/cager/repos/barapost2/tests/test_read_write/data/test_input/some_seqs.fastq.gz',
    ],
    output_dirpath='/home/masikol/Downloads/tmp/ooo',
    probing_batch_size=-1,
    packet_mode='seq_count',
    packet_size=3,
    max_seq_len=-1,
    blast_algorithm='megaBlast',
    organisms=[2, 10239]
)

# %%
prober_kernel = ProberKernel(args)

# %%
prober_kernel.run()
# Out:
# INFO:root:Found that 1 sequences from file `/home/masikol/cager/repos/barapost2/tests/test_remote_blast/data/query_corona_seq.fasta` have been already classified
# INFO:root:Found that 7 sequences from file `/home/masikol/cager/repos/barapost2/tests/test_read_write/data/test_input/some_seqs.fastq.gz` have been already classified
#     Would you like to resume the previous run?
#        1 -- Yes, resume!
#        2 -- Remove the old results and start from the beginning.
#        3 -- Archive the old results and start from the beginning.
#        4 -- Exit now.
#
#     Enter a number (1 or 2 or 3 or 4):>>  2
# INFO:root:You have chosen to remove the old results and start from the beginning.
# INFO:root:Emptying directory: `/home/masikol/Downloads/tmp/ooo/classification`...
# INFO:root:Done.
# INFO:root:Emptying directory: `/home/masikol/Downloads/tmp/ooo/tmp`...
# INFO:root:Done.
# ...
